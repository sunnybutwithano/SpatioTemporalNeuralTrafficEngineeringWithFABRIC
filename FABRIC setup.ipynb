# %% [markdown]
# ### Configure environment

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager
fablib = fablib_manager() 
conf = fablib.show_config()
# Out:
# <style type="text/css">
# #T_db603 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_db603 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_db603 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_db603_row0_col0, #T_db603_row0_col1, #T_db603_row1_col0, #T_db603_row1_col1, #T_db603_row2_col0, #T_db603_row2_col1, #T_db603_row3_col0, #T_db603_row3_col1, #T_db603_row4_col0, #T_db603_row4_col1, #T_db603_row5_col0, #T_db603_row5_col1, #T_db603_row6_col0, #T_db603_row6_col1, #T_db603_row7_col0, #T_db603_row7_col1, #T_db603_row8_col0, #T_db603_row8_col1, #T_db603_row9_col0, #T_db603_row9_col1, #T_db603_row10_col0, #T_db603_row10_col1, #T_db603_row11_col0, #T_db603_row11_col1, #T_db603_row12_col0, #T_db603_row12_col1, #T_db603_row13_col0, #T_db603_row13_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_db603">
#   <caption>FABlib Config</caption>
# ...

# %% [markdown]
# ## My topology

# %%
########## my code
slice_name="project" + fablib.get_bastion_username()

node_conf = [
 {'name': "Los-Angeles",   'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']}, 
 {'name': "Seattle",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']}, 
 {'name': "Denver",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
    
 {'name': "Server-LA",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
 {'name': "Client-Sea",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
 {'name': "Client-Denv",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
    
 {'name': "Minneapolis",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
 {'name': "Dallas",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
 {'name': "Chicago",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
 {'name': "Atlanta",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
 {'name': "Miami",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
 {'name': "New-York",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
    
 {'name': "Client-Minn",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
 {'name': "Server-Dal",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
 {'name': "Server-Chi",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
 {'name': "Client-Mia",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
 {'name': "Client-NY",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},   
    
]
net_conf = [
 {"name": "net_LA_to_Server", "subnet": "10.10.1.0/24", 
  "nodes": [{"name": "Los-Angeles",  "addr": "10.10.1.100"}, {"name": "Server-LA", "addr": "10.10.1.10"}]},
 {"name": "net_Sea_to_Client", "subnet": "10.10.2.0/24", 
  "nodes": [{"name": "Seattle", "addr": "10.10.2.100"}, {"name": "Client-Sea", "addr": "10.10.2.10"}]},
 {"name": "net_Denv_to_Client", "subnet": "10.10.3.0/24", 
  "nodes": [{"name": "Denver", "addr": "10.10.3.100"}, {"name": "Client-Denv", "addr": "10.10.3.10"}]},
 {"name": "net_LA_to_Sea", "subnet": "10.10.4.0/24", 
  "nodes": [{"name": "Los-Angeles", "addr": "10.10.4.100"}, {"name": "Seattle", "addr": "10.10.4.10"}]},
 {"name": "net_LA_to_Denv", "subnet": "10.10.5.0/24", 
  "nodes": [{"name": "Los-Angeles", "addr": "10.10.5.100"}, {"name": "Denver", "addr": "10.10.5.10"}]},
 {"name": "net_Sea_to_Denv", "subnet": "10.10.6.0/24", 
  "nodes": [{"name": "Denver", "addr": "10.10.6.100"}, {"name": "Seattle", "addr": "10.10.6.10"}]},

 {"name": "net_Minn_to_Client", "subnet": "10.10.7.0/24", 
  "nodes": [{"name": "Minneapolis", "addr": "10.10.7.100"}, {"name": "Client-Minn", "addr": "10.10.7.10"}]},
 {"name": "net_Dal_to_Server", "subnet": "10.10.8.0/24", 
  "nodes": [{"name": "Dallas", "addr": "10.10.8.100"}, {"name": "Server-Dal", "addr": "10.10.8.10"}]},
 {"name": "net_Chi_to_Server", "subnet": "10.10.9.0/24", 
  "nodes": [{"name": "Chicago", "addr": "10.10.9.100"}, {"name": "Server-Chi", "addr": "10.10.9.10"}]},
 {"name": "net_NY_to_Client", "subnet": "10.10.10.0/24", 
  "nodes": [{"name": "New-York", "addr": "10.10.10.100"}, {"name": "Client-NY", "addr": "10.10.10.10"}]},
 {"name": "net_Mia_to_Client", "subnet": "10.10.11.0/24", 
  "nodes": [{"name": "Miami", "addr": "10.10.11.100"}, {"name": "Client-Mia", "addr": "10.10.11.10"}]},

 {"name": "net_Dal_to_Denv", "subnet": "10.10.12.0/24", 
  "nodes": [{"name": "Dallas", "addr": "10.10.12.100"}, {"name": "Denver", "addr": "10.10.12.10"}]},
 {"name": "net_Minn_to_Denv", "subnet": "10.10.13.0/24", 
  "nodes": [{"name": "Minneapolis", "addr": "10.10.13.100"}, {"name": "Denver", "addr": "10.10.13.10"}]},
 {"name": "net_Minn_to_Dal", "subnet": "10.10.14.0/24", 
  "nodes": [{"name": "Minneapolis", "addr": "10.10.14.100"}, {"name": "Dallas", "addr": "10.10.14.10"}]},
 {"name": "net_Minn_to_Chi", "subnet": "10.10.15.0/24", 
  "nodes": [{"name": "Minneapolis", "addr": "10.10.15.100"}, {"name": "Chicago", "addr": "10.10.15.10"}]},
 {"name": "net_Dal_to_Atl", "subnet": "10.10.16.0/24", 
  "nodes": [{"name": "Dallas", "addr": "10.10.16.100"}, {"name": "Atlanta", "addr": "10.10.16.10"}]},
 {"name": "net_Dal_to_Mia", "subnet": "10.10.17.0/24", 
  "nodes": [{"name": "Dallas", "addr": "10.10.17.100"}, {"name": "Miami", "addr": "10.10.17.10"}]},
 {"name": "net_Atl_to_Mia", "subnet": "10.10.18.0/24", 
  "nodes": [{"name": "Atlanta", "addr": "10.10.18.100"}, {"name": "Miami", "addr": "10.10.18.10"}]},
 {"name": "net_Atl_to_Chi", "subnet": "10.10.19.0/24", 
  "nodes": [{"name": "Atlanta", "addr": "10.10.19.100"}, {"name": "Chicago", "addr": "10.10.19.10"}]},
 {"name": "net_NY_to_Chi", "subnet": "10.10.20.0/24", 
  "nodes": [{"name": "New-York", "addr": "10.10.20.100"}, {"name": "Chicago", "addr": "10.10.20.10"}]},
 {"name": "net_NY_to_Atl", "subnet": "10.10.21.0/24", 
  "nodes": [{"name": "New-York", "addr": "10.10.21.100"}, {"name": "Atlanta", "addr": "10.10.21.10"}]},
    
]

route_conf = [
 # {"addr": "10.10.2.0/24", "gw": "10.10.1.100", "nodes": ["Server-LA"]},
 # {"addr": "10.10.3.0/24", "gw": "10.10.1.100", "nodes": ["Server-LA"]},
    
    #Every host passes to the nearby router ================================================================
   {"addr": "10.10.0.0/19", "gw": "10.10.1.100", "nodes": ["Server-LA"]},
   {"addr": "10.10.0.0/19", "gw": "10.10.2.100", "nodes": ["Client-Sea"]},
   {"addr": "10.10.0.0/19", "gw": "10.10.3.100", "nodes": ["Client-Denv"]},
   {"addr": "10.10.0.0/19", "gw": "10.10.7.100", "nodes": ["Client-Minn"]},
   {"addr": "10.10.0.0/19", "gw": "10.10.8.100", "nodes": ["Server-Dal"]},
   {"addr": "10.10.0.0/19", "gw": "10.10.9.100", "nodes": ["Server-Chi"]},
   {"addr": "10.10.0.0/19", "gw": "10.10.10.100", "nodes": ["Client-NY"]},
   {"addr": "10.10.0.0/19", "gw": "10.10.11.100", "nodes": ["Client-Mia"]},
   
    #Router to router ======================================================================================
    
    # LA
    {"addr": "10.10.2.0/24", "gw": "10.10.4.10", "nodes": ["Los-Angeles"]}, # LA to Seattle goes to Seattle
    {"addr": "10.10.3.0/24", "gw": "10.10.5.10", "nodes": ["Los-Angeles"]}, # LA to Denver goes to Denver
    {"addr": "10.10.7.0/24", "gw": "10.10.5.10", "nodes": ["Los-Angeles"]}, # LA to Minneapolis goes to Denver
    {"addr": "10.10.8.0/24", "gw": "10.10.5.10", "nodes": ["Los-Angeles"]}, # LA to Dallas goes to Denver
    {"addr": "10.10.9.0/24", "gw": "10.10.5.10", "nodes": ["Los-Angeles"]}, # LA to Chicago goes to Denver
    {"addr": "10.10.10.0/24", "gw": "10.10.5.10", "nodes": ["Los-Angeles"]}, # LA to NY goes to Denver
    {"addr": "10.10.11.0/24", "gw": "10.10.5.10", "nodes": ["Los-Angeles"]}, # LA to Miami goes to Denver
    
    # Seattle
    {"addr": "10.10.1.0/24", "gw": "10.10.4.100", "nodes": ["Seattle"]}, # Seattle to LA goes to LA
    {"addr": "10.10.3.0/24", "gw": "10.10.6.100", "nodes": ["Seattle"]}, # Seattle to Denver goes to Denver
    {"addr": "10.10.7.0/24", "gw": "10.10.6.100", "nodes": ["Seattle"]}, # Seattle to Minneapolis goes to Denver
    {"addr": "10.10.8.0/24", "gw": "10.10.6.100", "nodes": ["Seattle"]}, # Seattle to Dallas goes to Denver
    {"addr": "10.10.9.0/24", "gw": "10.10.6.100", "nodes": ["Seattle"]}, # Seattle to Chicago goes to Denver
    {"addr": "10.10.10.0/24", "gw": "10.10.6.100", "nodes": ["Seattle"]}, # Seattle to NY goes to Denver
    {"addr": "10.10.11.0/24", "gw": "10.10.6.100", "nodes": ["Seattle"]}, # Seattle to Miami goes to Denver
    
    # Denver
    {"addr": "10.10.1.0/24", "gw": "10.10.5.100", "nodes": ["Denver"]}, # Denver to LA goes to LA
    {"addr": "10.10.2.0/24", "gw": "10.10.6.10", "nodes": ["Denver"]}, # Denver to Seattle goes to Denver
    {"addr": "10.10.7.0/24", "gw": "10.10.13.100", "nodes": ["Denver"]}, # Denver to Minneapolis goes to Minneapolis
    {"addr": "10.10.8.0/24", "gw": "10.10.12.100", "nodes": ["Denver"]}, # Denver to Dallas goes to Dallas
    {"addr": "10.10.9.0/24", "gw": "10.10.13.100", "nodes": ["Denver"]}, # Denver to Chicago goes to Minneapolis
    {"addr": "10.10.10.0/24", "gw": "10.10.12.100", "nodes": ["Denver"]}, # Denver to NY goes to Dallas
    {"addr": "10.10.11.0/24", "gw": "10.10.12.100", "nodes": ["Denver"]}, # Denver to Miami goes to Dallas
    
    # Minneapolis
    {"addr": "10.10.1.0/24", "gw": "10.10.13.10", "nodes": ["Minneapolis"]}, # Minneapolis to LA goes to Denver
    {"addr": "10.10.2.0/24", "gw": "10.10.13.10", "nodes": ["Minneapolis"]}, # Minneapolis to Seattle goes to Denver
    {"addr": "10.10.3.0/24", "gw": "10.10.13.10", "nodes": ["Minneapolis"]}, # Minneapolis to Denver goes to Denver
    {"addr": "10.10.8.0/24", "gw": "10.10.14.10", "nodes": ["Minneapolis"]}, # Minneapolis to Dallas goes to Dallas
    {"addr": "10.10.9.0/24", "gw": "10.10.15.10", "nodes": ["Minneapolis"]}, # Minneapolis to Chicago goes to Chicago
    {"addr": "10.10.10.0/24", "gw": "10.10.15.10", "nodes": ["Minneapolis"]}, # Minneapolis to NY goes to Chicago
    {"addr": "10.10.11.0/24", "gw": "10.10.14.10", "nodes": ["Minneapolis"]}, # Minneapolis to Miami goes to Dallas
    
    # Dallas
    {"addr": "10.10.1.0/24", "gw": "10.10.12.10", "nodes": ["Dallas"]}, # Dallas to LA goes to Denver
    {"addr": "10.10.2.0/24", "gw": "10.10.12.10", "nodes": ["Dallas"]}, # Dallas to Seattle goes to Denver
    {"addr": "10.10.3.0/24", "gw": "10.10.12.10", "nodes": ["Dallas"]}, # Dallas to Denver goes to Denver
    {"addr": "10.10.7.0/24", "gw": "10.10.14.100", "nodes": ["Dallas"]}, # Dallas to Minneapolis goes to Minneapolis
    {"addr": "10.10.9.0/24", "gw": "10.10.16.10", "nodes": ["Dallas"]}, # Dallas to Chicago goes to Atlanta
    {"addr": "10.10.10.0/24", "gw": "10.10.16.10", "nodes": ["Dallas"]}, # Dallas to NY goes to Atlanta
    {"addr": "10.10.11.0/24", "gw": "10.10.17.10", "nodes": ["Dallas"]}, # Dallas to Miami goes to Miami
    
    # Miami
    {"addr": "10.10.1.0/24", "gw": "10.10.17.100", "nodes": ["Miami"]}, # Miami to LA goes to Dallas
    {"addr": "10.10.2.0/24", "gw": "10.10.17.100", "nodes": ["Miami"]}, # Miami to Seattle goes to Dallas
    {"addr": "10.10.3.0/24", "gw": "10.10.17.100", "nodes": ["Miami"]}, # Miami to Denver goes to Dallas
    {"addr": "10.10.7.0/24", "gw": "10.10.17.100", "nodes": ["Miami"]}, # Miami to Minneapolis goes to Dallas
    {"addr": "10.10.9.0/24", "gw": "10.10.18.100", "nodes": ["Miami"]}, # Miami to Chicago goes to Atlanta
    {"addr": "10.10.10.0/24", "gw": "10.10.18.10", "nodes": ["Miami"]}, # Miami to NY goes to Atlanta
    {"addr": "10.10.8.0/24", "gw": "10.10.17.100", "nodes": ["Miami"]}, # Miami to Dallas goes to Dallas
    
    # Atlanta
    {"addr": "10.10.1.0/24", "gw": "10.10.16.100", "nodes": ["Atlanta"]}, # Atlanta to LA goes to Dallas
    {"addr": "10.10.2.0/24", "gw": "10.10.16.100", "nodes": ["Atlanta"]}, # Atlanta to Seattle goes to Dallas
    {"addr": "10.10.3.0/24", "gw": "10.10.16.100", "nodes": ["Atlanta"]}, # Atlanta to Denver goes to Dallas
    {"addr": "10.10.7.0/24", "gw": "10.10.19.10", "nodes": ["Atlanta"]}, # Atlanta to Minneapolis goes to Chicago
    {"addr": "10.10.9.0/24", "gw": "10.10.19.10", "nodes": ["Atlanta"]}, # Atlanta to Chicago goes to Chicago
    {"addr": "10.10.10.0/24", "gw": "10.10.21.100", "nodes": ["Atlanta"]}, # Atlanta to NY goes to NY
    {"addr": "10.10.8.0/24", "gw": "10.10.16.100", "nodes": ["Atlanta"]}, # Atlanta to Dallas goes to Dallas
    {"addr": "10.10.11.0/24", "gw": "10.10.18.10", "nodes": ["Atlanta"]}, # Atlanta to Miami goes to Miami
    
    # Chicago
    {"addr": "10.10.1.0/24", "gw": "10.10.15.100", "nodes": ["Chicago"]}, # Chicago to LA goes to Minneapolis
    {"addr": "10.10.2.0/24", "gw": "10.10.15.100", "nodes": ["Chicago"]}, # Chicago to Seattle goes to Minneapolis
    {"addr": "10.10.3.0/24", "gw": "10.10.15.100", "nodes": ["Chicago"]}, # Chicago to Denver goes to Minneapolis
    {"addr": "10.10.7.0/24", "gw": "10.10.15.10", "nodes": ["Chicago"]}, # Chicago to Minneapolis goes to Minneapolis
    {"addr": "10.10.10.0/24", "gw": "10.10.20.100", "nodes": ["Chicago"]}, # Chicago to NY goes to NY
    {"addr": "10.10.8.0/24", "gw": "10.10.19.100", "nodes": ["Chicago"]}, # Chicago to Dallas goes to Atlanta
    {"addr": "10.10.11.0/24", "gw": "10.10.19.100", "nodes": ["Chicago"]}, # Chicago to Miami goes to Atlanta
    
    # NY
    {"addr": "10.10.1.0/24", "gw": "10.10.21.10", "nodes": ["New-York"]}, # NY to LA goes to Atlanta
    {"addr": "10.10.2.0/24", "gw": "10.10.20.10", "nodes": ["New-York"]}, # NY to Seattle goes to Chicago
    {"addr": "10.10.3.0/24", "gw": "10.10.21.10", "nodes": ["New-York"]}, # NY to Denver goes to Atlanta
    {"addr": "10.10.7.0/24", "gw": "10.10.20.10", "nodes": ["New-York"]}, # NY to Minneapolis goes to Chicago
    {"addr": "10.10.9.0/24", "gw": "10.10.20.10", "nodes": ["New-York"]}, # NY to Chicago goes to Chicago
    {"addr": "10.10.8.0/24", "gw": "10.10.21.10", "nodes": ["New-York"]}, # NY to Dallas goes to Atlanta
    {"addr": "10.10.11.0/24", "gw": "10.10.21.10", "nodes": ["New-York"]}, # NY to Miami goes to Atlant
    
    
#  {"addr": "10.10.2.0/24", "gw": "10.10.4.10", "nodes": ["Los-Angeles"]},
#  {"addr": "10.10.3.0/24", "gw": "10.10.5.10", "nodes": ["Los-Angeles"]},
    
#  {"addr": "10.10.1.0/24", "gw": "10.10.2.100", "nodes": ["Client-Sea"]},
#  {"addr": "10.10.3.0/24", "gw": "10.10.2.100", "nodes": ["Client-Sea"]},
    
#  {"addr": "10.10.3.0/24", "gw": "10.10.6.100", "nodes": ["Seattle"]},
#  {"addr": "10.10.1.0/24", "gw": "10.10.4.100", "nodes": ["Seattle"]},
    
         
#  {"addr": "10.10.1.0/24", "gw": "10.10.3.100", "nodes": ["Client-Denv"]},
#  {"addr": "10.10.2.0/24", "gw": "10.10.3.100", "nodes": ["Client-Denv"]},
    
#  {"addr": "10.10.1.0/24", "gw": "10.10.5.100", "nodes": ["Denver"]},
#  {"addr": "10.10.2.0/24", "gw": "10.10.6.10", "nodes": ["Denver"]},
    
    #for 13 and above
]
exp_conf = {'cores': sum([ n['cores'] for n in node_conf]), 'nic': sum([len(n['nodes']) for n in net_conf]) }

# %%
########## my code only for the west coast
slice_name="west-coast" + fablib.get_bastion_username()

node_conf = [

{'name': "Los-Angeles",   'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']}, 
{'name': "Seattle",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']}, 
{'name': "Denver",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
    
{'name': "Server-LA",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
{'name': "Client-Sea",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
{'name': "Client-Denv",  'cores': 1, 'ram': 1, 'disk': 1, 'image': 'default_ubuntu_20', 'packages': ['net-tools', 'iperf3', 'moreutils']},
    
]

net_conf = [

 {
    "name": "net_LA_to_Server", "subnet": "10.10.1.0/24", 
    "nodes": [{"name": "Los-Angeles",  "addr": "10.10.1.100"}, {"name": "Server-LA", "addr": "10.10.1.10"}]
 },
 {
    "name": "net_Sea_to_Client", "subnet": "10.10.2.0/24", 
    "nodes": [{"name": "Seattle", "addr": "10.10.2.100"}, {"name": "Client-Sea", "addr": "10.10.2.10"}]
 },
 {
    "name": "net_Denv_to_Client", "subnet": "10.10.3.0/24", 
    "nodes": [{"name": "Denver", "addr": "10.10.3.100"}, {"name": "Client-Denv", "addr": "10.10.3.10"}]
 },
 {
    "name": "net_LA_to_Sea", "subnet": "10.10.4.0/24", 
    "nodes": [{"name": "Los-Angeles", "addr": "10.10.4.100"}, {"name": "Seattle", "addr": "10.10.4.10"}]
 },
 {
    "name": "net_LA_to_Denv", "subnet": "10.10.5.0/24", 
    "nodes": [{"name": "Los-Angeles", "addr": "10.10.5.100"}, {"name": "Denver", "addr": "10.10.5.10"}]
 },
 {
    "name": "net_Sea_to_Denv", "subnet": "10.10.6.0/24", 
    "nodes": [{"name": "Denver", "addr": "10.10.6.100"}, {"name": "Seattle", "addr": "10.10.6.10"}]
 },
       
]
# I'm not sure about this
route_conf = [ 
 {"addr": "10.10.2.0/24", "gw": "10.10.1.100", "nodes": ["Server-LA"]},
 {"addr": "10.10.3.0/24", "gw": "10.10.1.100", "nodes": ["Server-LA"]},
    
 {"addr": "10.10.2.0/24", "gw": "10.10.4.10", "nodes": ["Los-Angeles"]},
 {"addr": "10.10.3.0/24", "gw": "10.10.5.10", "nodes": ["Los-Angeles"]},
    
 {"addr": "10.10.1.0/24", "gw": "10.10.2.100", "nodes": ["Client-Sea"]},
 {"addr": "10.10.3.0/24", "gw": "10.10.2.100", "nodes": ["Client-Sea"]},
    
 {"addr": "10.10.3.0/24", "gw": "10.10.6.100", "nodes": ["Seattle"]},
 {"addr": "10.10.1.0/24", "gw": "10.10.4.100", "nodes": ["Seattle"]},
    
         
 {"addr": "10.10.1.0/24", "gw": "10.10.3.100", "nodes": ["Client-Denv"]},
 {"addr": "10.10.2.0/24", "gw": "10.10.3.100", "nodes": ["Client-Denv"]},
    
 {"addr": "10.10.1.0/24", "gw": "10.10.5.100", "nodes": ["Denver"]},
 {"addr": "10.10.2.0/24", "gw": "10.10.6.10", "nodes": ["Denver"]},
    
    #for 13 and above
]
exp_conf = {'cores': sum([ n['cores'] for n in node_conf]), 'nic': sum([len(n['nodes']) for n in net_conf]) }

# %% [markdown]
# ### Reserve resources

# %%
try:
    slice = fablib.get_slice(slice_name)
    print(slice)
    print("You already have a slice by this name!")
    print("If you previously reserved resources, skip to the 'log in to resources' section.")
except:
    print("You don't have a slice named %s yet." % slice_name)
    print("Continue to the next step to make one.")
    slice = fablib.new_slice(name=slice_name)
# Out:
# You don't have a slice named projectsmousa13_0000111581 yet.
# Continue to the next step to make one.

# %%
while True:
    site_name = fablib.get_random_site()
    
    if ( (fablib.resources.get_core_available(site_name) > 1.2 * exp_conf['cores']) and 
        (fablib.resources.get_component_available(site_name, 'SharedNIC-ConnectX-6') > 1.2 * exp_conf['nic']) ):
        break

fablib.show_site(site_name)
# Out:
# <style type="text/css">
# #T_a9e0b tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_a9e0b tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_a9e0b caption {
#   text-align: center;
#   font-size: 150%;
# }
# ...

# %%
# this cell sets up the nodes
for n in node_conf:
    slice.add_node(name=n['name'], site=site_name, 
                   cores=n['cores'], 
                   ram=n['ram'], 
                   disk=n['disk'], 
                   image=n['image'])

# %%
# this cell sets up the network segments
for n in net_conf:
    ifaces = [slice.get_node(node["name"]).add_component(model="NIC_Basic", 
                                                 name=n["name"]).get_interfaces()[0] for node in n['nodes'] ]
    slice.add_l2network(name=n["name"], type='L2Bridge', interfaces=ifaces)

# %%
slice.submit()
# Out:
# Retry: 49, Time: 3919 sec
# <style type="text/css">
# #T_cdb3f tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_cdb3f tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_cdb3f caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_cdb3f_row0_col0, #T_cdb3f_row0_col1, #T_cdb3f_row1_col0, #T_cdb3f_row1_col1, #T_cdb3f_row2_col0, #T_cdb3f_row2_col1, #T_cdb3f_row3_col0, #T_cdb3f_row3_col1, #T_cdb3f_row4_col0, #T_cdb3f_row4_col1, #T_cdb3f_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_cdb3f_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_cdb3f">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cdb3f_row0_col0" class="data row0 col0" >ID</td>
# ...

# %%
slice.get_state()
slice.wait_ssh(progress=True)
# Out:
# Waiting for slice . Slice state: StableOK
# Waiting for ssh in slice . ssh successful
# True

# %% [markdown]
# ### Configure resources
#
# Next, we will configure the resources so they are ready to use.

# %%
slice = fablib.get_slice(name=slice_name)

# %%
# install packages
# this will take a while and will run in background while you do other steps
for n in node_conf:
    if len(n['packages']):
        node = slice.get_node(n['name'])
        pkg = " ".join(n['packages'])
        node.execute_thread("sudo apt update; sudo apt -y install %s" % pkg)

# %%
# bring interfaces up and either assign an address (if there is one) or flush address
from ipaddress import ip_address, IPv4Address, IPv4Network

for net in net_conf:
    for n in net['nodes']:
        if_name = n['name'] + '-' + net['name'] + '-p1'
        iface = slice.get_interface(if_name)
        iface.ip_link_up()
        if n['addr']:
            iface.ip_addr_add(addr=n['addr'], subnet=IPv4Network(net['subnet']))
        else:
            iface.get_node().execute("sudo ip addr flush dev %s"  % iface.get_device_name())

# %%
# prepare a "hosts" file that has names and addresses of every node
# DO NOT RUN THIS PLEASE
hosts_txt = [ "%s\t%s" % ( n['addr'], n['name'] ) for net in net_conf  for n in net['nodes'] if type(n) is dict and n['addr']]
for n in slice.get_nodes():
    for h in hosts_txt:
        n.execute("echo %s | sudo tee -a /etc/hosts" % h)

# %%
# enable IPv4 forwarding on all nodes
for n in slice.get_nodes():
    n.execute("sudo sysctl -w net.ipv4.ip_forward=1")

# %%
# set up static routes
for rt in route_conf:
    for n in rt['nodes']:
        slice.get_node(name=n).ip_route_add(subnet=IPv4Network(rt['addr']), gateway=rt['gw'])

# %%
for n in node_conf:
    node = slice.get_node(n['name'])
    print(node.get_name())
    print(node.get_ip_routes())
    print('=========================')
# Out:
# Los-Angeles
# ...

# %% [markdown]
# ### Extend your slice
#
# If you don’t plan to finish an experiment in one day, you can extend your slice. The following cell extends your reservation for 7 days.

# %%
from datetime import datetime
from datetime import timezone
from datetime import timedelta

# Set end date to 7 days from now
end_date = (datetime.now(timezone.utc) + timedelta(days=7)).strftime("%Y-%m-%d %H:%M:%S %z")
slice.renew(end_date)

# %% [markdown]
# ### Draw the network topology

# %% [markdown]
# The following cell will draw the network topology, for your reference. The interface name and addresses of each experiment interface will be shown on the drawing.

# %%
l2_nets = [(n.get_name(), {'color': 'lavender'}) for n in slice.get_l2networks() ]
l3_nets = [(n.get_name(), {'color': 'pink'}) for n in slice.get_l3networks() ]
hosts   =   [(n.get_name(), {'color': 'lightblue'}) for n in slice.get_nodes()]
nodes = l2_nets + l3_nets + hosts
ifaces = [iface.toDict() for iface in slice.get_interfaces()]
edges = [(iface['network'], iface['node'], 
          {'label': iface['physical_dev'] + '\n' + iface['ip_addr'] + '\n' + iface['mac']}) for iface in ifaces]

# %%
for n in nodes:
    if 'Client' in n[0] or 'Server' in n[0]:
        if 'net' in n[0]:
            pass
        else:
            n[1]['color'] = 'lime'
    elif not 'net' in n[0]:
        n[1]['color'] = 'orange'

# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.figure(figsize=(len(nodes),len(nodes)))
G = nx.Graph()
G.add_nodes_from(nodes)
G.add_edges_from(edges)
pos = nx.spring_layout(G)
nx.draw(G, pos, node_shape='o',  
        node_color=[n[1]['color'] for n in nodes], 
        # node_size=[len(n[0])*400 for n in nodes], 
        node_size=23000,
        with_labels=False);
nx.draw_networkx_edge_labels(G,pos,
                             edge_labels=nx.get_edge_attributes(G,'label'),
                             font_color='gray',  font_size=8, rotate=False);
from matplotlib.pyplot import figure, text
for node, (x, y) in pos.items():
    if 'net' in node:
        if 'Client' in node or 'Server' in node:
            label = 'edge\nnetwork'
        else:
            label = 'inter\nrouter\nnetwork'
    else:
        label = node.replace('-', '\n')
    text(x, y, label, fontsize=32, ha='center', va='center')

# %% [markdown]
# ### Log into resources

# %%
for n in slice.get_nodes():
    print(n.get_name(), n.get_ssh_command())
# Out:
# Seattle ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:e0:a04c:fab2:f816:3eff:feee:5fca
# Denver ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}
# Server-LA ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}
# Client-Sea ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}
# Client-Denv ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}
# Minneapolis ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}
# ...

# %% [markdown]
# ## Working with Slice

# %%
slice.get_node("Los-Angeles").download_file("/home/fabric/work/adaptive-video/flow/LAtoDenv.txt", "/home/ubuntu/flow.txt")
slice.get_node("Seattle").download_file("/home/fabric/work/adaptive-video/flow/SeatoDenv.txt", "/home/ubuntu/flow.txt")
slice.get_node("Denver").download_file("/home/fabric/work/adaptive-video/flow/DenvtoMinn.txt", "/home/ubuntu/flow.txt")
slice.get_node("Dallas").download_file("/home/fabric/work/adaptive-video/flow/DaltoDenv.txt", "/home/ubuntu/flow.txt")
slice.get_node("Miami").download_file("/home/fabric/work/adaptive-video/flow/MiatoAtl.txt", "/home/ubuntu/flow.txt")
slice.get_node("Atlanta").download_file("/home/fabric/work/adaptive-video/flow/AtltoDal.txt", "/home/ubuntu/flow.txt")
slice.get_node("Chicago").download_file("/home/fabric/work/adaptive-video/flow/ChitoAtl.txt", "/home/ubuntu/flow.txt")
slice.get_node("New-York").download_file("/home/fabric/work/adaptive-video/flow/NYtoAtl.txt", "/home/ubuntu/flow.txt")
# slice.get_node("Seattle").download_file("/home/ubuntu/flowLADenv.txt", "/home/ubuntu/flow/LAtoDenv.txt")

# %%
! pwd
# Out:
# /home/fabric/work/adaptive-video/notebooks

# %% [markdown]
# ### Delete

# %%
slice = fablib.get_slice(name=slice_name)
fablib.delete_slice(slice_name)

# %%
slice.update()
_ = slice.show()
# Out:
# <style type="text/css">
# #T_620ea tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_620ea tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_620ea caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_620ea_row0_col0, #T_620ea_row0_col1, #T_620ea_row1_col0, #T_620ea_row1_col1, #T_620ea_row2_col0, #T_620ea_row2_col1, #T_620ea_row3_col0, #T_620ea_row3_col1, #T_620ea_row4_col0, #T_620ea_row4_col1, #T_620ea_row5_col0, #T_620ea_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_620ea">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_620ea_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_620ea_row0_col1" class="data row0 col1" >d7174f45-36c4-46e5-bbb3-bfa6242d2b09</td>
#     </tr>
#     <tr>
#       <td id="T_620ea_row1_col0" class="data row1 col0" >Name</td>
# ...
